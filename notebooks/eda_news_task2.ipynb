# %%
import pandas as pd
import re
import nltk

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df = pd.read_csv("../data/news.csv")
df.head()
# Out:
#                                             title  \
# 0                   Stocks rally on tech earnings
# 1         Oil prices drop amid global uncertainty
# 2  Federal Reserve keeps interest rates unchanged
# 3               Crypto market sees strong inflows
# 4                Gold falls as dollar strengthens
#
#                                                 text     label
# 0  Tech companies reported strong quarterly earni...  positive
# 1  Crude oil prices declined sharply as demand we...  negative
# 2  The central bank maintained interest rates ami...   neutral
# 3  Digital assets rose as investor sentiment impr...  positive
# 4  Gold prices dropped due to a stronger U.S. dol...  negative

# %%
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

def clean_text(text):
    text = text.lower()
    text = re.sub(r"[^a-zA-Z\s]", "", text)
    tokens = text.split()
    tokens = [t for t in tokens if t not in stop_words]
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    return " ".join(tokens)

# %%
df["clean_text"] = df["text"].apply(clean_text)
df.head()
# Out:
#                                             title  \
# 0                   Stocks rally on tech earnings
# 1         Oil prices drop amid global uncertainty
# 2  Federal Reserve keeps interest rates unchanged
# 3               Crypto market sees strong inflows
# 4                Gold falls as dollar strengthens
#
#                                                 text     label  \
# 0  Tech companies reported strong quarterly earni...  positive
# 1  Crude oil prices declined sharply as demand we...  negative
# 2  The central bank maintained interest rates ami...   neutral
# 3  Digital assets rose as investor sentiment impr...  positive
# 4  Gold prices dropped due to a stronger U.S. dol...  negative
#
#                                           clean_text
# 0  tech company reported strong quarterly earning...
# 1  crude oil price declined sharply demand weaken...
# 2  central bank maintained interest rate amid slo...
# 3     digital asset rose investor sentiment improved
# 4           gold price dropped due stronger u dollar
